# %%
import pandas as pd

titanic = pd.read_csv("Titanic-Dataset.csv")
print("<-------------------------------------------titanic---------------------------------------------->")
df = pd.DataFrame(titanic)
print(df)
# Out:
# <-------------------------------------------titanic---------------------------------------------->
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
print("<-------------------------------------------head---------------------------------------------->")
print(df.head())
print("<-------------------------------------------tail---------------------------------------------->")
print(df.tail())
# Out:
# <-------------------------------------------head---------------------------------------------->
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
print("<-------------------------------------------dtypes---------------------------------------------->")
print(df.dtypes)
print("<-------------------------------------------info---------------------------------------------->")
print(df.info())
# Out:
# <-------------------------------------------dtypes---------------------------------------------->
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object
# <-------------------------------------------info---------------------------------------------->
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
# ...

# %%
#handling specific column 
print("<-------------------------------------------handling specific column---------------------------------------------->")
age = df['Age'].head()
print(age)
print(type(age))
print(age.shape)

print("<-------------------------------------------handling multiple column---------------------------------------------->")
age_sex = titanic[['Age','Sex']].to_string()
print(age_sex)
# Out:
# <-------------------------------------------handling specific column---------------------------------------------->
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# Name: Age, dtype: float64
# <class 'pandas.core.series.Series'>
# (5,)
# <-------------------------------------------handling multiple column---------------------------------------------->
#        Age     Sex
# 0    22.00    male
# 1    38.00  female
# 2    26.00  female
# 3    35.00  female
# 4    35.00    male
# 5      NaN    male
# 6    54.00    male
# 7     2.00    male
# 8    27.00  female
# 9    14.00  female
# 10    4.00  female
# 11   58.00  female
# 12   20.00    male
# 13   39.00    male
# 14   14.00  female
# 15   55.00  female
# 16    2.00    male
# 17     NaN    male
# 18   31.00  female
# 19     NaN  female
# 20   35.00    male
# 21   34.00    male
# 22   15.00  female
# 23   28.00    male
# 24    8.00  female
# 25   38.00  female
# 26     NaN    male
# 27   19.00    male
# 28     NaN  female
# ...

# %%
print("<-------------------------------------------compare---------------------------------------------->")
print(df['Age']>20)

print(type(df['Age']))
# Out:
# <-------------------------------------------compare---------------------------------------------->
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 886     True
# 887    False
# 888    False
# 889     True
# 890     True
# Name: Age, Length: 891, dtype: bool
# <class 'pandas.core.series.Series'>
